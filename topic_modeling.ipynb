# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaleab1999/topic-modeling/blob/main/topic_modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bertopic
# Out:
# Successfully installed bertopic-0.12.0 hdbscan-0.8.29 huggingface-hub-0.11.1 pynndescent-0.5.8 pyyaml-5.4.1 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.13.2 transformers-4.25.1 umap-learn-0.5.3

# %%
from bertopic import BERTopic
import pandas as pd

# %%
df= pd.read_csv('/content/merge-csv.com__6361876ee50a8.csv', encoding= 'unicode_escape')

# %%
df.head()
# Out:
#                 created_at       user_id              name     label  \
# 0  2022-10-28 23:15:24 UTC  4.386524e+08       AfricanSon®  negative
# 1  2022-10-28 22:53:28 UTC  1.320000e+18      Bargo YOUSIF  negative
# 2  2022-10-28 22:21:31 UTC  8.226798e+08  Dr. Aklog Birara  positive
# 3  2022-10-28 19:46:19 UTC  1.470000e+18              bill  negative
# 4  2022-10-28 16:40:48 UTC  1.570000e+18          OverMeon   neutral
#
#                                                tweet language  \
# 0  Ethiopian Airlines (EA) flight ET-3717 was int...       en
# 1  _ details: It's #Ethiopian_Airlines flight, sm...       en
# 2  I look forward to seeing integrated infrastruc...       en
# 3  @jaeyoonieee me getting on ethiopian airlines ...       en
# 4  #ETH552 ET-AVE A350 941 Ethiopian Airlines ADD...       en
#
#                                                 link  Column1
# 0  https://twitter.com/samsenge/status/1586134568...      NaN
# 1  https://twitter.com/BargoYousif/status/1586129...      NaN
# 2  https://twitter.com/DrAklogBirara/status/15861...      NaN
# 3  https://twitter.com/ysfkd_/status/158608195096...      NaN
# 4  https://twitter.com/OverMeon/status/1586035262...      NaN

# %%
data = df['tweet']
data.head()
# Out:
# 0    Ethiopian Airlines (EA) flight ET-3717 was int...
# 1    _ details: It's #Ethiopian_Airlines flight, sm...
# 2    I look forward to seeing integrated infrastruc...
# 3    @jaeyoonieee me getting on ethiopian airlines ...
# 4    #ETH552 ET-AVE A350 941 Ethiopian Airlines ADD...
# Name: tweet, dtype: object

# %%
# !pip install text-hammer

# %%
import spacy
import re
import text_hammer as th
nlp=  spacy.load('en_core_web_sm')

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from gensim.parsing.preprocessing import remove_stopwords
from nltk.stem import WordNetLemmatizer
  
lemmatizer = WordNetLemmatizer()

# %%
def text_preprocessor(x):

  doc = nlp(x)
  
  text= [word.lemma_.lower().strip() for word in doc ]
  text = str(x).lower().replace('\\', '').replace('_', ' ')
  text = th.cont_exp(text)
  text = th.remove_emails(text)
  text = th.remove_urls(text)
  text = th.remove_html_tags(text)
  text = th.remove_rt(text)
  text = th.remove_accented_chars(text)
  text = th.remove_special_chars(text)
  text = re.sub("(.)\\1{2,}", "\\1", text)
  text= re.sub('[^a-zA-Z]', ' ',text)

  text = lemmatizer.lemmatize(text, pos='a')
  #text= text if text not in stopwords else " "
  filtered_sentence = remove_stopwords(text)

  return filtered_sentence

# %%
data= df['tweet'].apply(text_preprocessor)

# %%
# create object 
topic_model= BERTopic(language='english')

# %%
# change dataframe to list
docs= data.tolist()

# %%
topics, probs = topic_model.fit_transform(docs)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
topic_model.get_topic_freq()
# Out:
#      Topic  Count
# 0       -1   1170
# 1        0    104
# 2        1     99
# 3        2     99
# 4        3     89
# ..     ...    ...
# 112    111     11
# 113    112     11
# 114    113     11
# 115    114     10
# 116    115     10
#
# [117 rows x 2 columns]

# %%
topic_model.get_topic(100)
# Out:
# [('speed', 0.14604619757937726),
#  ('altitude', 0.14604619757937726),
#  ('distance', 0.14250787958156616),
#  ('featuring', 0.13632564822360307),
#  ('squawk', 0.13632564822360307),
#  ('arriving', 0.1335919616191252),
#  ('haab', 0.12393624808322491),
#  ('egcc', 0.12393624808322491),
#  ('kingdom', 0.12393624808322491),
#  ('miles', 0.1223953485464013)]

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="
class="plotly-graph-div" style="height:750px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dfcc2031-e971-4bb8-a985-afb5a50a2f81")) {                    Plotly.newPlot(                        "dfcc2031-e971-4bb8-a985-afb5a50a2f81",                        [{"hoverinfo":"text","hovertext":["supper service start menu having smoked fish start lamb turmeric stew ethiopian airlines right sample ethiopian food","reliable cargo mover sky ethiopianairlines thenewspiritofafrica","ethiopian airlines expansion project eal symbol excellence","cnnafrica sudanese evil jealousy neighboring ethiopia ethiopian airlines nile river gerd dam","flyethiopian caption ethiopian airlines going great distances support tigraygenocide","pls reliable telephone contact ethiopian airlines sisters ghana flight addis got messed","ethiopian airlines truly african pride flyethiopian es flyethiopian monami wekesa amos","blenmamodt mfaethiopia ethiopiadublin irlembethiopia ethioembassyuk etfactcheck mufti dina muferihatk tsionag berhanutsegaye geduandargachew fagethiopia truly amazing countries ireland terrorist tplf plse close ethio embassy ireland ethiopian airlines refuel rome","ethiopian airlines crippled tool tigraygenocide way russian airlines punishedsecblinken boycottethiopianairlines usambun swedenun nlatun canadianpm","brother pilot ethiopian airlines today took son work","vivutio tanzania ethiopian airlines adds ninth european destination","ethiopian airlines ceo record service tokyo vienna jakarta manila los angeles madrid works ethiopianairlines","big ups ethiopian airlines","flyethiopian waiting hour services","cairo cape town ethiopian airlines eur","tigraygenocide usgov needs sanction ethiopianairlines ethiopiancommercialbank stop getting help financially transportation abiyahmedali potus cnni unsc josepborrellf borisjohnson irishmissionun","time travel ethiopian airlines sunday late nite india ghana overall good experience cabin crew goodhumble served ground staff mishandled luggage bit disappointed team work makes airlines best flyethiopian","eslemanabbay flyethiopian minusma sooner later ethiopian airlines awarded nobel prize outstanding service second largest continent cradle humanity","got addis ethiopian airlines dreamliner firmly establishes et african aviation superpower","etano eth ethiopian airlines ethiopia boeing lr ethiopian airlines add bole addis ababa ethiopia iad washington dulles united states alt ft seen times scotradar","country director ethiopian airlines abbey egesa advised uganda national airlines company consider cargo transportation domestic travel key components operations national flag carrier uganda airlines letsbuildug ugmoving wd","years april ethiopian airlines scheduled flight cairo asmara douglas c skytrain flyethiopian yearsofexcellence et","ethiopian airlines boost india flights eyes higher traffic brics","afdb approves usd m loan ethiopian airlines finance expansion plan fleet modernization program","evdb praise ethiopian airlines","flyethiopian au disappointing lot headquarter ed ethiopia possible try associate oau","theradiolioness flyethiopian enjoy fun honey","addisale flyethiopian forget expense employees","ethiopian airlines partners iocc consulting","mihretum z architect ethiopia great continental expansion success later global combankethiopia ethiotelecom raise coffee export times higher b ethiopia major actor beneficial afcfta logistics agri export learn flyethiopian","ethiopian airlines best airline rd consecutive year","regal halima abdulshakur duty east africa culture arts festival represents oromia delegates nations culture africa visitoromia flyethiopian ethiopia landoforigins tourism","ethiopian airlines kindly ...

# %%
topic_model.reduce_topics(docs, nr_topics=50)

# %%
topic_model.get_topic_freq()
# Out:
#     Topic  Count
# 0      -1   1570
# 1       0    129
# 2       1    125
# 3       2    107
# 4       3    107
# 5       4    104
# 6       5    104
# 7       6     91
# 8       7     90
# 9       8     81
# 10      9     81
# 11     10     80
# 12     11     76
# 13     12     74
# 14     13     69
# 15     14     66
# 16     15     65
# 17     16     65
# 18     17     64
# 19     18     52
# 20     19     52
# 21     20     51
# 22     21     51
# 23     22     50
# 24     23     48
# 25     24     47
# 26     25     46
# 27     26     45
# 28     27     42
# 29     28     42
# 30     29     42
# 31     30     40
# 32     31     39
# 33     32     39
# 34     33     38
# 35     34     38
# 36     35     38
# 37     36     38
# 38     37     37
# 39     38     36
# 40     39     36
# 41     40     36
# 42     41     36
# 43     42     35
# 44     43     35
# 45     44     33
# 46     45     32
# 47     46     32
# 48     47     32
# 49     48     32
# 50     49     31

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4076de6a-8d37-495c-a50c-fa270c2bdddf" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4076de6a-8d37-495c-a50c-fa270c2bdddf")) {                    Plotly.newPlot(                        "4076de6a-8d37-495c-a50c-fa270c2bdddf",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.05287435384849266,0.05436723570904318,0.061193970943581116,0.07237075830796773,0.15566856428012088],"y":["nigerian  ","fg  ","operators  ","air  ","nigeria  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.03977794985941657,0.04740115600494648,0.047803983830654186,0.04901562561785048,0.07685876206968274],"y":["za  ","india  ","zurich  ","bengaluru  ","chennai  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.05006584463364427,0.05840172707916205,0.06999093560337843,0.07537467345403356,0.09698449719325399],"y":["saa  ","carrier  ","largest  ","revenue  ","profit  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.04204686130660223,0.04224930336842738,0.04294833926838462,0.04473455650774664,0.061332289988291475],"y":["refund  ","email  ","flyethiopian  ","message  ","customer  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.040253889027628324,0.04097967193257397,0.04196500865274475,0.05775234656414037,0.08618166181874312],"y":["lost  ","missing  ","baggage  ","bag  ","luggage  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.04388274197419171,0.048450145792559185,0.055601718022551344,0.059535955634699475,0.08329886558444066],"y":["tigray  ","sanctions  ","transporting  ","soldiers  ","weapons  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.05278069116160724,0.0703129122542874,0.07117331631530943,0.07457597387946942,0.08221529613322699],"y":["separation  ","kinshasa  ","update  ","brazzaville  ","february  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.10516625760390765,0.10724049735571699,0.12079953872566075,0.12270706899789002,0.15560659782130665],"y":["africas  ","order  ","orders  ","companies  ","airbus  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"] ...

# %% [markdown]
# #### updating the existed model

# %%
topic_model.update_topics(docs, n_gram_range=(2, 2))

# %%
topic_model.get_topic_freq().head(6)
# Out:
#    Topic  Count
# 0     -1   1570
# 1      0    129
# 2      1    125
# 3      2    107
# 4      3    107
# 5      4    104

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="38fc8419-b733-4d9d-8283-04e054901efc" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38fc8419-b733-4d9d-8283-04e054901efc")) {                    Plotly.newPlot(                        "38fc8419-b733-4d9d-8283-04e054901efc",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.03434683394216347,0.03434683394216347,0.04030305696923304,0.04989333929482594,0.10965674530557393],"y":["involvement nigeria  ","airlines involvement  ","national carrier  ","nigeria ethiopian  ","nigeria air  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.021102363705815055,0.021102363705815055,0.025611421086534733,0.031541931812681556,0.03979283904489975],"y":["bengaluru india  ","thrice weekly  ","new flight  ","weekly flights  ","za rich  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.04107837594243364,0.04219325669331766,0.044916032881142216,0.052816389017358474,0.05706904137167367],"y":["largest african  ","fastest growing  ","airlines largest  ","carrier revenue  ","revenue profit  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.023456468407799767,0.023456468407799767,0.033566745529315406,0.04518282754643148,0.054017468948084305],"y":["options avoid  ","consideration customers  ","worst customer  ","direct message  ","customer service  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.015682619626808933,0.015682619626808933,0.015682619626808933,0.018332069797573226,0.02030383610188365],"y":["airline passenger  ","passenger luggage  ","lost baggage  ","flyethiopian ethiopian  ","worst airline  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.024051851518198535,0.02751849902712717,0.028013031124907484,0.03017623627571564,0.0368320878376382],"y":["transport weapons  ","soldiers weapons  ","transporting weapons  ","airlines transporting  ","weapons soldiers  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.05248448853201206,0.052835220832189944,0.052835220832189944,0.052835220832189944,0.05741989227348967],"y":["airlines expands  ","brazzaville flights  ","separation kinshasa  ","airlines separation  ","kinshasa brazzaville  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.08866311654922426,0.1103674518022484,0.11617394389813969,0.12905615126700004,0.13667505479679887],"y":["airbus companies  ","africas airbus  ","airlines orders  ","orders africas  ","companies news  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c17 ...
